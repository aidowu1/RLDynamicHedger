# %% [markdown]
# ### RLDynamicHedger Reward Curves For Trained (hyper-parameter tuned) RL Models
#  - This notebook is used to demo the reward curves generated during the training of the RL agents

# %% [markdown]
# #### Imports

# %%
import os, sys
import numpy as np

SEED = 100
NEW_LINE = "\n"

np.random.seed(SEED)

# %% [markdown]
# #### Set current working directory..

# %%
ROOT_PATH = "../"
os.chdir(ROOT_PATH)
print(f"Current path is: {os.getcwd()}...{NEW_LINE}")
# Out:
# Current path is: C:\Development\Training\MLI Certificate of Finance\Final-Project\Project\RLDynamicHedger-Final...

# %% [markdown]
# #### Libaries for RLDynamicHedger

# %%
from scripts.generate_rl_reward_plots import GeneratePlots
# Out:
# Root folder: C:\Development\Training\MLI Certificate of Finance\Final-Project\Project\RLDynamicHedger-Final\scripts\..

# %% [markdown]
# #### Generate the reward curves

# %%
generate_plots = GeneratePlots(is_plot_2_screen=True)
generate_plots.plotRLModelRewardCurves()
# Out:
# 2025-04-22 23:23:14,481 - INFO - generate_rl_reward_plots.py:plotRLModelRewardCurves - : RL Model Reward Curves Generated Successfully... in C:\Development\Training\MLI Certificate of Finance\Final-Project\Project\RLDynamicHedger-Final\scripts\generate_rl_reward_plots.py:97
